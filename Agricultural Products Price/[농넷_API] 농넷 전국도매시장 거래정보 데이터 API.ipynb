# %%
import pandas as pd
import urllib.request
import json
import datetime

# %% [markdown]
# ### 어제의 농넷 데이터 불러오기

# %% [markdown]
# 시간별, 도매시장별로 데이터가 계속 추가 업데이트 됩니다.
# 전체 데이터를 얻기 위해서 하루 전날(D-1)을 선택.

# %%
today = datetime.datetime.today()
yesterday = (today - datetime.timedelta(1)).strftime('%Y%m%d') 
url = 'https://www.nongnet.or.kr/api/whlslDstrQr.do?sdate=' # sdate = 날짜

response = urllib.request.urlopen(url+yesterday).read()
response = json.loads(response)

data = pd.DataFrame(response['data'])

# %%
data #ALL_TSALET_ALL_ 데이터와 같은 형식
# Out:
#        PUM_NM LV_NM  TOT_AMT  SAN_NM  SALEDATE CMP_NM DAN_NM WHSAL_NM  \
# 0          곶감     특  1440000  경북 성주군  20210913   두레청과     kg   광주서부도매
# 1          곶감     특  1440000  경북 성주군  20210913   두레청과     kg   광주서부도매
# 2          곶감     특  1440000  경북 성주군  20210913   두레청과     kg   광주서부도매
# 3          곶감     특   400000  경북 성주군  20210913   두레청과     kg   광주서부도매
# 4          사과     특   900000  전북 장수군  20210913   두레청과     kg   광주서부도매
# ...       ...   ...      ...     ...       ...    ...    ...      ...
# 172845    바나나     .   315000    None  20210913   강서청과     kg   서울강서도매
# 172846    바나나     .   189000    None  20210913   강서청과     kg   서울강서도매
# 172847    바나나     .   105000    None  20210913   강서청과     kg   서울강서도매
# 172848    바나나     .   105000    None  20210913   강서청과     kg   서울강서도매
# 172849    바나나     .   105000    None  20210913   강서청과     kg   서울강서도매
#
#          SIZE_NM   COST POJ_NM  TOT_QTY    QTY  KIND_NM  DANQ
# 0              .   4800     상자    150.0  300.0     함안곶감   0.5
# 1              .   4800     상자    150.0  300.0     함안곶감   0.5
# 2              .   4800     상자    150.0  300.0     함안곶감   0.5
# 3              .   4000     상자    100.0  100.0     함안곶감   1.0
# 4              .  20000    파렛트    225.0   45.0       홍로   5.0
# ...          ...    ...    ...      ...    ...      ...   ...
# 172845  1개(내_뿌리)  21000      .    195.0   15.0  바나나(수입)  13.0
# 172846  1개(내_뿌리)  21000      .    117.0    9.0  바나나(수입)  13.0
# 172847  1개(내_뿌리)  21000      .     65.0    5.0  바나나(수입)  13.0
# 172848  1개(내_뿌리)  21000      .     65.0    5.0  바나나(수입)  13.0
# 172849  1개(내_뿌리)  21000      .     65.0    5.0  바나나(수입)  13.0
#
# [172850 rows x 15 columns]

# %% [markdown]
# ### 이후에는 Baseline용 전처리 방식, 혹은 참가자만의 방식 등으로 전처리해주시면 됩니다.
# 'AT_TSALET_ALL 파일 전처리 코드' 참고 링크: https://dacon.io/competitions/official/235801/codeshare/3233?page=1&dtype=recent
